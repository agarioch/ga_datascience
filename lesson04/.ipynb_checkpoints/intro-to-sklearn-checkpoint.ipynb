# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Introduction to  `scikit-learn`
#
#
# ---
#
# <img src="https://avatars2.githubusercontent.com/u/365630?v=3&s=400" style="width: 300px; float: left; margin: 20px; margin-top: -20px; break: right;"><img src="https://snag.gy/qfaubJ.jpg" style="width: 300px; float: left; margin: 20px;">
#
# <br clear="all">
#
#
# ### Learning Objectives
# - Overview of what scikit-learn modules are used for
# - Learn how to build a linear regression model with scikit-learn
# - Practice building models using scikit-learn
# - Interpret the output of models

# %% [markdown]
# ### Lesson Guide
# - [Machine Learning](#machinelearning)
# - [`sklearn`](#intro)
# - [Looking at the documentation](#documentation)
# - [History of scikit-learn](#sklearn-background)
# - [First steps with sklearn](#sklearn-first-steps)
# - [Fitting a model with sklearn](#first-model-sklearn)
# - [sklearn model class attributes](#model-attributes)
# - [Review metrics for evaluating regression models](#common-metrics)
# - [Fit a MLR using sklearn](#mlr-sklearn)
# - [A note on negative $R^2$ values](#negative-r2)
# - [Independent practice](#independent-practice)

# %% [markdown]
# ## Machine Learning
#
# We have seen how we can divide most of our modelling tasks into three: clustering, predicting numbers and predicting classes.
#
# The techniques for solving this tasks usually fall into what's called **Machine Learning**.
#
# **Machine Learning provides us with the ability to make computer do "intelligent" things, without being explicitely programmed.** They use past data to train models that will (hopefully) predict future points with reasonable accuracy, or find interesting segmentations in the data.
#
# One of the main and best developed frameworks for machine learning is sklearn, which we will use extensively througout this course.

# %% [markdown]
# <a id='intro'></a>
#
# ##  `sklearn`
#
# ---
#
# This lesson intends to introduce the modeling package `sklearn` in the context of regression modeling.
#
# In general:
# - **`sklearn`** is the *machine learning* package
#
#
# Though the terms have immense overlap, machine learning tends to be more prediction focused while statistics is more inference focused.
#
# **Remember: even with all the power provided by these modeling tools, it's never a replacement for good EDA!**
#
# ---
#
# ### A preface on modeling
#
# As we venture down the path of modeling, it can be difficult to determine which choices are "correct" or "incorrect".  A primary challenge is to understand how different models will perform in different circumstances and different types of data. It's essential to practice modeling on a variety of data.
#
# As a beginner it is essential to learn which metrics are important for evaluating your models and what they mean. The metrics we evaluate our models with inform our actions.
#
# *Exploring datasets on your own with the skills and tools you learn in class is highly recommended!*

# %% [markdown]
# ## Seaborn intermezzo
#
# Before we dig into the actual modelling, let's go through simple example of EDA, so you can add a couple more tools to that "EDA" toolbox

# %% [markdown]
# <a id="intro-to-seaborn"></a>
# ## Intro to Seaborn
# ---
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics.
#
# Examples of the types of plots you can make with seaborn can be found here:
#
# https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# <a id="plotting-relationships"></a>
# ## Plotting relationships
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Our sample data
x = (60, 61, 62, 63, 65)
y = (3.1, 3.6, 3.8, 4, 4.1)

sample_data = list(zip(x, y))
df = pd.DataFrame(sample_data, columns=["x", "y"])

# plot the data with regplot
my_plot = df.plot(kind="scatter", x="x", y="y", title="Sample Data", figsize=(10, 5))

# Add value markers because it's nice to have a visual reference to data points
for point in sample_data:
    my_plot.text(point[0] + .2, point[1] - .02, str(point))

sns.regplot(x="x", y="y", data=df);

# %%
tips = sns.load_dataset("tips")
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.pairplot(tips, kind="reg")

# %% [markdown]
# <img src="./assets/title.png">

# %% [markdown]
# ## Example Correlation Matrix
# <img src="./assets/corr.png">

# %% [markdown]
# ## Same Correlation Matrix in seaborn...
# <img src="./assets/heatmap.png">

# %% [markdown]
# ## The power of Boxplots
# <img src="./assets/boxplot.png">

# %% [markdown]
# <a id='documentation'></a>
#
# ## `sklearn`  documentation
#
# ---
#
# Get familiar with looking up things in the `sklearn` documentation. You are going to be doing a lot of it over this data science course and beyond.
#
# [The sklearn documentation can be found here.](http://scikit-learn.org/stable/documentation.html)
#
# Below is an example for linear regression in sklearn:
#
# * [Linear regression in scikit-learn](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)
#
# If you haven't yet, familliarize yourself with the format of the documentation.

# %% [markdown]
# <a id='sklearn-background'></a>
#
# ## Background: Scikit-learn / sklearn
#
# ---
#
# <img src="https://avatars1.githubusercontent.com/u/25111?v=3&s=200" style="float: left; margin: 0 25px;"> Scikit-learn was founded in 2007 as a Google summer of code project by [David Cournapeau](https://github.com/cournape).  Later in 2007, Matthieu Brucher published his thesis on Scikit-learn.  Since then, the Scikit-learn project has taken on a worldwide team of owners. A great high level overview of the project can be found in a 2011 publication in [Journal of Machine Learning Research 12 (2011) 2825-2830](http://www.jmlr.org/papers/volume12/pedregosa11a/pedregosa11a.pdf).
#
# Scikit-learn is part of the Scipy family of "kits".  Explore some of the [other projects](https://scikits.appspot.com/scikits) in this family.
# <br clear="all"><br>
#
#
# **Scikit-learn provides a wide variety of machine learning models, including:**
#
# - Linear regression
# - Logistic regression
# - Support Vector Machines
# - Classification And Regression Tree Models
# - Naive Bayes
# - Clustering Models (K-Means, Hierarchical, DBScan)
#
# **It also handles the construction of typical machine learning pipeline utilities for:**
# - Model evaluation
# - Model selection
# - Preprocessing
# - Natural Language Processing
# - Dimensionality Reduction
#
# **Scikit-learn comes with a ton of datasets that are cleaned and formatted to work with the models provided by their library:**
# - Boston Housing
# - Iris Flowers
# - Diabetes Diagnostics
# - Various sample images (for classification)
#   - Faces
#   - MINIST (handwriting examples)
# - Random data generators
# - Spam examples
# - Newsgroup classfication
#
# [Read more about Scikit-learn datasets](http://scikit-learn.org/stable/datasets/)
#
# ---

# %% [markdown]
# ### `sklearn` under the hood
#
# - **Numpy**:  The base for data structures and transformations. Input data is represented as numpy arrays, integrating seamlessly with other scientific Python libraries. Numpy’s viewbased memory model limits copies, even when binding with compiled code.  It also provides basic arithmetic and linear algebra operations.<br><br>
#
# - **Scipy**:  Efficient algorithms for linear algebra, sparse matrix representation, special functions and basic statistical functions.<br><br>
#
# - **Cython**:  A language for combining C with Python. Cython makes it easy to reach the performance of compiled languages with Python-like syntax and high-level operations.

# %% [markdown]
# <a id='sklearn-first-steps'></a>
#
# ## First steps with `sklearn`: loading the data
#
# ---
#
# We will load the boston housing dataset using sklearn and then construct and fit a linear regression model on the data.

# %%
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error

# Don't forget to turn on plotting display in the notebook
# %matplotlib inline

# %% [markdown]
# **Load the diabetes data with the `datasets.load_diabetes()` function.**

# %% [markdown]
# ### AG: Swapping diabetes data set for boston house price dataset

# %%
new_cols = ['crime_rate', 'res_land', 'ind_land', 'chas_river', 'nox', 'rooms', '<1940', 'dis_work', 'highways', 'tax', 'p_teach_ratio', 'black_pop', 'low_status']

# %%
len(new_cols)
# Out:
# 13

# %%
data = datasets.load_boston()

print (data.DESCR) # This is like a data dictionary!
# Out:
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
# ...

# %% [markdown]
# **The data object we've loaded has attributes with the features, target variable, and design matrix:**

# %%
print (data.feature_names)
print (data.data[0:3])
print (data.target[0:3])
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
# [[  6.32000000e-03   1.80000000e+01   2.31000000e+00   0.00000000e+00
#     5.38000000e-01   6.57500000e+00   6.52000000e+01   4.09000000e+00
#     1.00000000e+00   2.96000000e+02   1.53000000e+01   3.96900000e+02
#     4.98000000e+00]
#  [  2.73100000e-02   0.00000000e+00   7.07000000e+00   0.00000000e+00
#     4.69000000e-01   6.42100000e+00   7.89000000e+01   4.96710000e+00
#     2.00000000e+00   2.42000000e+02   1.78000000e+01   3.96900000e+02
#     9.14000000e+00]
#  [  2.72900000e-02   0.00000000e+00   7.07000000e+00   0.00000000e+00
#     4.69000000e-01   7.18500000e+00   6.11000000e+01   4.96710000e+00
#     2.00000000e+00   2.42000000e+02   1.78000000e+01   3.92830000e+02
#     4.03000000e+00]]
# [ 24.   21.6  34.7]

# %% [markdown]
# ### Putting the data in pandas for convenience
#
# Our target is what we are predicting.  Sometimes this is called the **response variable**.
#
# The target and the data are what we use to train, or **fit** the model with.
#
# Scikit-learn has already split our data into the **predictors** and **response** for us. It has also stored the names of the features in a separate array.
#
# So we can print things like the header of the data it will be more convenient to have our data in a pandas dataframe.
#
# **Use the predictors and the feature names to create a pandas dataframe.**

# %%
import numpy as np
import pandas as pd

# Create dataframe of main data to use as predictors (later). AKA "X"
df = pd.DataFrame(data.data, columns=data.feature_names)

# target vector
target = data.target

print (df.shape)
print (target.shape)
df.head()
# Out:
# (506, 13)
# (506,)
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# # Our training set is a matrix / dataframe with many variables (**AGE, SEX, BMI, BP, S1, S2, S3, S4, S5, and S6**). We have **10** predictors with **442** rows/observations.
#
# Our target is a vector that represents a single variable (**column 11**), which has exactly the same number of observations as our training set: **442**.
#
# > _Training (fit) and target datasets must always match in length!_

# %% [markdown]
# ### Index correspondence between target and predictors
#
# # Row 0 of **`df`**, our training data, is:

# %%
df[0:1]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.09  1.0  296.0     15.3
#
#        B  LSTAT
# 0  396.9   4.98

# %% [markdown]
# This corresponds to the 0 index obersvation in our target vector:

# %%
target[0]
# Out:
# 24.0

# %% [markdown]
# These two seperate datasets (a matrix/dataframe, and a vector), are what we will use in the `.fit(predictors, target)` function in sklearn's models.
#
# - The training data is 2D with dimensions: `n_samples x n_features`
# - The response is 1D with dimensions: `n_samples`, matching the `n_samples` of the training data.

# %% [markdown]
# <a id='first-model-sklearn'></a>
#
# ## Fitting our 1st model with `sklearn`
#
# ---
#
# Now let's fit a linear regression model with the housing data.
#
# First let's visually identify some predictors that seem to have a relationship with house value.
#
# **Plot bp and bmi against the target variable with seaborn.**
#
# > _Note: If for some reason scikit-learn crashes the jupyter notebook, have conda remove mkl (there's an issue with the newer build on some systems)._

# %%
max(target)
# Out:
# 50.0

# %%
sns.distplot(target)

# %%
ax = sns.jointplot(df.rooms.values, target, kind='hex', edgecolor = 'white')
ax.set_axis_labels('Avg. Number Rooms', 'Median House Price')

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
df.columns = new_cols

# %%
df.head()
# Out:
#    crime_rate  res_land  ind_land  chas_river    nox  rooms  <1940  dis_work  \
# 0     0.00632      18.0      2.31         0.0  0.538  6.575   65.2    4.0900
# 1     0.02731       0.0      7.07         0.0  0.469  6.421   78.9    4.9671
# 2     0.02729       0.0      7.07         0.0  0.469  7.185   61.1    4.9671
# 3     0.03237       0.0      2.18         0.0  0.458  6.998   45.8    6.0622
# 4     0.06905       0.0      2.18         0.0  0.458  7.147   54.2    6.0622
#
#    highways    tax  p_teach_ratio  black_pop  low_status
# 0       1.0  296.0           15.3     396.90        4.98
# 1       2.0  242.0           17.8     396.90        9.14
# 2       2.0  242.0           17.8     392.83        4.03
# 3       3.0  222.0           18.7     394.63        2.94
# 4       3.0  222.0           18.7     396.90        5.33

# %%
sns.jointplot(df.dis_work.values, target)

# %% [markdown]
# **Below we fit a linear regression model predicting `MEDV` (the target vector) from `RM`.**
#
# > **Note:** sklearn models expect the predictor matrix to be 2D and the target to be 1D.

# %%
lm = linear_model.LinearRegression()

X = df[["dis_work"]]
y = target 

model = lm.fit(X, y)

# %% [markdown]
# **Make predictions for the X matrix using `.predict(X)`, and score the model ($R^2$) using `model.score(X, y)`.**
#
# Plot the predicted values against the true values of the target, and print the model $R^2$.
#
# > **`.score(predictors, target)`**: a class method / function that returns the coefficient of determination R^2 of the prediction (for regression models).  Found in many models in scikit-learn (but not all).

# %%
predictions  =  model.predict(X)
score        =  model.score(X, y)

# Plot the model
plt.figure(figsize=(10,8))
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted diabetes score from distance to work centers - $\hat{y}$")
plt.ylabel("Actual median house values  - y")
plt.show()

print ("score: ", score)
# Out:
# score:  0.0624643721218

# %% [markdown]
# **What can this plot tell us about the model?**

# %%
# If the points all fell on a diagonal line then we would have a perfect fit.
# The more "cloud-like" this becomes, the worse our fit will be.

# %% [markdown]
# <a id='model-attributes'></a>
#
# ## sklearn model class attributes
#
# ---
#
# After you run `.fit()`, a sklearn model object often contains a variety of calculated metrics, coefficients, and other information. Which metrics and attributes are present will depend on the model – consult the documentation for specifics.
#
# Attributes in the `LinearRegression` object include:
# - **`.coef_`**: property containing the coeffients for the predictor variables
# - **`.intercept_`**: value of the intercept
#
# **Print out the beta coefficient and intercept for the model.**

# %%
print (model.coef_)
print (model.intercept_)
# Out:
# [ 1.09161302]
# 18.3900883305

# %% [markdown]
# **What does the coefficient mean in the context of your model?**

# %%
# A 1 unit increase in variable BMI corresponds to a 949.44 unit increase 
# in the estimate of MEDV

# %% [markdown]
# <a id='common-metrics'></a>
#
# ## Review: common metrics for evaluating regression models
#
# ---
#
# The [root mean squared error (RMSE)](https://en.wikipedia.org/wiki/Root-mean-square_deviation) is a standard measure of model performance. It is the square root of the mean of the sum of squared residuals:
#
# ### $$ \operatorname{RMSE}= \sqrt{\frac{1}{n}\sum_{i=1}^n(\hat{y_i} - y_i)^2} $$
#
# The smaller the root mean squared error, the better your model fits the data.
#
# You are already familiar with the [coefficient of determination $R^2$](https://en.wikipedia.org/wiki/Coefficient_of_determination):
#
# ### $$ R^2 = 1 - \frac{SS_{reg}}{SS_{tot}} $$
#
# Where the regression sum of squares is the sum of squared residuals for our model:
#
# $SS_{reg}=\sum_i (\hat{y} -\bar{y})^2$
#
# And the total sum of squares is the sum of squared residuals for the *baseline* model. This is essentially the variance of our target.
#
# $SS_{tot} = \sum_i (y_i-\bar{y})^2$
#
# $R^2$ is the most common metric to evaluate a regression and is the default scoring measure in sklearn. When we cover classification models, the `.score` function instead defaults to accuracy.
#
#
# **Calculate the RMSE of your model by leveraging `sklearn.metrics.mean_squared_error`.**

# %%
from sklearn.metrics import mean_squared_error

print (np.sqrt(mean_squared_error(target, predictions)))
# Out:
# 8.89642296578

# %% [markdown]
# <a id='mlr-sklearn'></a>
#
# ## Fit a MLR using sklearn
#
# ---
#
# We have fit a simple linear regression predicting `diabetes score ~ bmi + 152` (where the 152 represents the intercept). Use the same sklearn process and `LinearRegression` model to estimate the target with both `bmi` and `bp`.

# %%
lm = linear_model.LinearRegression()

X = df[["dis_work","rooms"]].values
y = target

model = lm.fit(X, y)

predictions  =  model.predict(X)
score        =  model.score(X, y)

# Plot the model
plt.figure(figsize=(8,8))
plt.scatter(predictions, y, s=30, c='r', marker='+', zorder=10)
plt.xlabel("Predicted diabetes score from distance to work centers + avg. number rooms - $\hat{y}$")
plt.ylabel("Actual median value ($K) - y")
plt.show()

print ("score: ", score)
# Out:
# score:  0.495524647606

# %% [markdown]
# **Print out the coefficients from this MLR model and interpret them.**

# %%
print (model.coef_)
# Out:
# [ 0.48884854  8.80141183]

# %% [markdown]
# For a 1 mile increase in distance from key work centers there is a $500 increase (?!) in median house price values
#
# For each 1 additional room there is a $8.8K increase in median house values

# %% [markdown]
# <a id='negative-r2'></a>
#
# ## A note on negative $R^2$ values
#
# ---
#
# Over the course of this class you will encounter negative $R^2$ values. This may seem impossible, and it is in the standard scenario where we are calculating the $R^2$ score on the data we fit the model with.
#
# However, if you fit your model on one sample of data, *then score the model on new data not used to fit the model*, it is possible to end up with negative $R^2$.
#
# **What does it mean to have a negative $R^2$?**
#
# Remember that $R^2$ is 1 minus the error of your regression model divided by the error of the baseline model. A negative $R^2$ means that the regression model is performing *worse* than the baseline model. In the context of fitting our data on one sample of data and scoring on another sample, this means that we would have been better off making predictions on the test sample just using the mean of the target variable in our training set.
#
# We will return to the topic of negative $R^2$ when we talk about training and testing sets and cross-validation.

# %% [markdown]
# ## Overfitting / Underfitting
# ![overfitting.png](attachment:overfitting.png)
#
#
# **What is wrong with the first model?**
# - The underfit model falls short of capturing the complexity of the "true model" of the data.
#
# **What is wrong with the third model?**
# - The overfit model is too complex and is modeling random noise in the data.
#
# **Middle model is a good compromise.**
# - It approximates the complexity of the true model and does not model random noise in our sample as true relationships.

# %% [markdown]
# ## Train Test Split
#
# So far we've focused on fitting the best model to our data. But is this the best model for our sample data or the best model overall? How do we know?
#
# In practice, we need to validate our model's ability to generalize to new data. One very popuplar method for performing model validation is by splitting our data into subsets: data that we *train* our model on, and data that we *test* our model on.
#
# The most basic type of "hold-out" validation is called **train-test split**. We split our data into two pieces:
#
# > **"Training set":** the subset of the data that we fit our model on.
#
# > **"Testing set":** the subset of the data that we evaluate the quality of our predictions on.
#
#
# **Test/train split benefits:**
# - Testing data can be a proxy for "future" data; for prediction-oriented models it is critical to make sure a model performing well on current data will likely perform well on future data.
# - Can help diagnose and avoid overfitting via model tuning.
# - Improve the quality of our predictions.

# %% [markdown]
# <a id='demo'></a>
#
# ## Train-test split with sklearn demonstration
#
# ---
#
# Let's use sklearn to reload the diabetes dataset

# %%
from matplotlib import pyplot as plt

import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns

from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')

# Load the Boston Housing dataset
boston = datasets.load_boston()
boston.keys()

#
df = pd.DataFrame(boston.data, columns=boston.feature_names)
y = boston.target

# Take a look at the data again
df.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT
# 0     15.3  396.9   4.98
# 1     17.8  396.9   9.14

# %% [markdown]
# <a id='heatmap'></a>
#
# ### Plot a heatmap of the correlation matrix
#
# Heatmaps are a great way to visually examine the correlational structure of your predictors.
#
# > Keep in mind that pearson correlation between non-dummy-coded categorical variables and other variables are invalid!

# %%
def correlation_heat_map(df):
    corrs = df.corr()
    sns.set(style='white')
    # Set the default matplotlib figure size:
    fig, ax = plt.subplots(figsize=(11,7))

    # Generate a mask for the upper triangle (taken from seaborn example gallery)
    mask = np.zeros_like(corrs, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Plot the heatmap with seaborn.
    # Assign the matplotlib axis the function returns. This will let us resize the labels.
    ax = sns.heatmap(corrs, mask=mask, annot=True)

    # Resize the labels.
    ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14, rotation=30)
    ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14, rotation=0)
    # If you put plt.show() at the bottom, it prevents those useless printouts from matplotlib.
    plt.show()

df_with_target = df.copy()
df_with_target['MEDV'] = y
correlation_heat_map(df_with_target)

# %% [markdown]
# <a id='single-predictor'></a>
#
# ### Select a single predictor for a SLR
#
# The variable `AGE` appears to have a minor linear relationship with the target variable, `MEDV`.
#
# Let's select just `AGE` out of the data as a single column design matrix.

# %%
X = df[['PTRATIO']]
X.head(3)
# Out:
#    PTRATIO
# 0     15.3
# 1     17.8
# 2     17.8

# %% [markdown]
# **Good practice to plot the variable against the target to confirm the relationship visually.**

# %%
sns.lmplot('PTRATIO','MEDV', df_with_target)
plt.show()

# %% [markdown]
# <a id='sklearn-tts'></a>
#
# ### sklearn's `train_test_split` function
#
# Train test split using sklearn is easy. Load the `train_test_split` function:
#
# ```python
# from sklearn.model_selection import train_test_split
# ```
#
# **Arguments**:
# - *arrays: Any number of arrays/matrices to split up into training and testing (they should be the same length).
# - `test_size`: an integer for exact size of the test subset or a float for a percentage
# - `train_size`: alternatively you can specify the training size
# - `stratify`: supply a vector to stratify the split (more important in classification tasks)
#
# **Perform a 70-30 split of our `X` and `y`:**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (354, 1) (354,)
# (152, 1) (152,)

# %%
X_train.head()
# Out:
#      PTRATIO
# 5       18.7
# 116     17.8
# 45      17.9
# 16      21.0
# 468     20.2

# %% [markdown]
# ### The baseline.
#
# How can we tell if our model is performing well or at the very least capturing some meaningfull patterns?
#
# In the presence of lots of noise in the data, it stands to reason that a model with a certain RMSE can be consider better than a model with the same score on a dataset with very little noise.
#
# One way of benchmarking our models against our (more or less noisy) data is to create a baseline model and then calculate the baseline score.
#
# In the case of regression, the baseline model is one that always predicts the mean value for the target. Given this model, its easy to compare that prediction against the test set, to get an Baseline RMSE score.
#
# You should always check if your model is at least improving upon the baseline. Otherwise you could say that your model is not actually doing anything useful.

# %%
# Baseline model
baseline = np.mean(y_test)
baseline
# Out:
# 21.407894736842106

# %%
# Baseline RMSE
baseline_pred = np.empty(len(y_test))
baseline_pred.fill(baseline)
print (np.sqrt(mean_squared_error(y_test, baseline_pred)))
# Out:
# 8.63209682336

# %% [markdown]
# <a id='fit-on-train'></a>
#
# ### Fit a linear regression on the training set
#
# Using the training `X` and training `y`, we can fit a linear regression with sklearn's `LinearRegression`.

# %%
from sklearn.linear_model import LinearRegression

slr = LinearRegression()
slr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# <a id='score-on-test'></a>
#
# ### Calculate the RMSE  score on the test data
#
# After we have our model constructed on the training set, we can evaluate how well our model performs on data it has no exposure to.

# %%
from sklearn.metrics import mean_squared_error

# %%
pred = slr.predict(X_test)

# %%
print (np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# 7.32575548093

# %% [markdown]
# **Compare this to the baseline model scored on the test set.**
#
# In this case, our trained model results in less error (62.32) than the baseline (73.47) and thus, we can say that our model performs better than the baseline.

# %% [markdown]
# <a id='independent-practice'></a>
#
# ## Independent practice
#
# ---
#
# Using sklearn, build a linear regression model using any set of **continuous** variables from the diabetes dataset of your choice. Evaluate your model using RMSE. Describe what the RMSE means.

# %%
# YOUR IMPLEMENTATION HERE
Xa = df[['PTRATIO', 'TAX', 'RM']]
Xa.head(3)
# Out:
#    PTRATIO    TAX     RM
# 0     15.3  296.0  6.575
# 1     17.8  242.0  6.421
# 2     17.8  242.0  7.185

# %%
Xa_train, Xa_test, ya_train, ya_test = train_test_split(Xa, y, test_size=0.3, random_state=42)

# %%
reg = LinearRegression()
reg.fit(Xa_train, ya_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
est = reg.predict(Xa_test)

# %%
np.sqrt(mean_squared_error(ya_test, est))
# Out:
# 5.4192905615524891

# %%
fig1 = sns.regplot(est, ya_test)
fig1.set(xlabel='Estimated median house price $K', ylabel='Actual median house price $K')
fig1.set_title('1. Model results')
plt.show()

# %%
fig2 = sns.regplot(baseline_pred, y_test)
fig2.set(xlabel='Estimated median house price $K', ylabel='Actual median house price $K')
fig2.set_title('2. Baseline results')
plt.show()
